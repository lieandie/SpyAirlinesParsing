# %%
import pandas as pd

# %%
point_forum_sirena_merged = pd.read_csv('assets/merged/forum_pointz_sirena.merged.csv')
loyality = pd.read_csv('assets/FrequentFlyerForum-Profiles.loyality.csv')
# Out:
# /home/lieandie/python/environments/jupiter/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2705: DtypeWarning: Columns (1,6,7,8,10,11,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
point_forum_sirena_merged.head()
# Out:
#    Unnamed: 0   sex first_name last_name  flight depart_date codeshare  \
# 0           0  Male        NaN       NaN  DL3377  2017-03-04     False
# 1           1  Male        NaN       NaN  DL3377  2017-03-04     False
# 2           2  Male        NaN       NaN  DL3598  2017-07-30     False
# 3           3  Male        NaN       NaN  DL3598  2017-07-30     False
# 4           4  Male        NaN       NaN  DL5498  2017-03-31     False
#
#     country_arrival   city_arrival airport_arrival       ...         \
# 0  United States of  Pittsburgh PA             PIT       ...
# 1  United States of  Pittsburgh PA             PIT       ...
# 2  United States of  Evansville IN             EVV       ...
# 3  United States of  Evansville IN             EVV       ...
# 4  United States of  Birmingham AI             BHM       ...
#
#          number birth_date arrival_date code_share code e_ticket document  \
# 0  KE 889215424        NaN          NaN        NaN  NaN      NaN      NaN
# ...

# %%
loyality.head()
# Out:
#    account_id  status        number
# 0           1   Basic  KE 889215424
# 1           1  Elite+  DT 484697244
# 2           2   Basic  SU 658121632
# 3           2  Elite+  DT 356246372
# 4           2   Basic  KE 388423193

# %%
merged = pd.merge(point_forum_sirena_merged, loyality, how='inner', on='number')

# %%
merged.drop(['account_id' ,'status_y'], axis=1, inplace=True)

# %%
merged.to_csv('assets/merged/merged_forum_members.csv')
