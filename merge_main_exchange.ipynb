# %%
import pandas as pd

# %%
pd.options.display.width = None
pd.options.display.max_columns=999

# %%
point_forum_sirena_merged = pd.read_csv('assets/merged/forum_pointz_sirena.merged.csv')
# Out:
# /home/lieandie/python/environments/jupiter/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (1,6,7,8,10,11,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
exchange = pd.read_csv('assets/merged/SkyTeam-Exchange.merged.csv')

# %%
point_forum_sirena_merged['depart_date'] = point_forum_sirena_merged['depart_date'].astype('datetime64[ns]')
exchange['date'] = exchange['date'].astype('datetime64[ns]')

# %%
exchange.drop(['status','to'], axis=1, inplace=True)

# %%
merged = pd.merge(point_forum_sirena_merged, exchange, how="outer", left_on=['flight', 'depart_date', 'airport_departure'], right_on=['id', 'date', 'from'])

# %%
merged.head()
# Out:
#    Unnamed: 0   sex first_name last_name  flight depart_date codeshare  \
# 0         0.0  Male        NaN       NaN  DL3377  2017-03-04     False
# 1         0.0  Male        NaN       NaN  DL3377  2017-03-04     False
# 2         1.0  Male        NaN       NaN  DL3377  2017-03-04     False
# 3         1.0  Male        NaN       NaN  DL3377  2017-03-04     False
# 4         2.0  Male        NaN       NaN  DL3598  2017-07-30     False
#
#     country_arrival   city_arrival airport_arrival country_departure  \
# 0  United States of  Pittsburgh PA             PIT  United States of
# 1  United States of  Pittsburgh PA             PIT  United States of
# 2  United States of  Pittsburgh PA             PIT  United States of
# 3  United States of  Pittsburgh PA             PIT  United States of
# 4  United States of  Evansville IN             EVV  United States of
#
#   city_departure airport_departure  status        number birth_date  \
# ...
